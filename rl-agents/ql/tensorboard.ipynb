# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Open TensorBoard inline
# %tensorboard --logdir ./qlearning_tensorboard
# Out:
#       <iframe id="tensorboard-frame-c197c4c2abbaeac4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c197c4c2abbaeac4");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
